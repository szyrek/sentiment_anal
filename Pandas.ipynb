# %% [markdown]
# <a href="https://colab.research.google.com/github/szyrek/sentiment_anal/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Pandas (only needed if not already installed)
# !pip install pandas

# Import Pandas
import pandas as pd

# Creating a DataFrame from a dictionary
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, 35, 40],
        'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']}
df = pd.DataFrame(data)
print("DataFrame:")
print(df)
# Out:
# ...
# DataFrame:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
# Accessing columns
print("\nAccessing columns:")
print("Name column:")
print(df['Name'])
print("Age column:")
print(df['Age'])

# Accessing rows
print("\nAccessing rows:")
print("First row:")
print(df.iloc[0])
print("Last row:")
print(df.iloc[-1])
# Out:
# Accessing columns:
# Name column:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object
# Age column:
# 0    25
# 1    30
# 2    35
# 3    40
# Name: Age, dtype: int64
#
# Accessing rows:
# First row:
# Name       Alice
# Age           25
# City    New York
# Name: 0, dtype: object
# Last row:
# Name      David
# Age          40
# City    Houston
# Name: 3, dtype: object

# %%
# Filtering data
print("\nFiltering data:")
print("People older than 30:")
print(df[df['Age'] > 30])
# Out:
# Filtering data:
# People older than 30:
#       Name  Age     City
# 2  Charlie   35  Chicago
# 3    David   40  Houston

# %%
# Reading data from a CSV file
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
titanic_df = pd.read_csv(url)
print("\nTitanic DataFrame:")
print(titanic_df.head())
# Out:
# Titanic DataFrame:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# Basic data analysis
print("\nBasic data analysis:")
print("Summary statistics:")
print(titanic_df.describe())
print("Number of passengers by class:")
print(titanic_df['Pclass'].value_counts())
# Out:
# Basic data analysis:
# Summary statistics:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# Number of passengers by class:
# ...

# %%
# Grouping and aggregating data
grouped_data = titanic_df.groupby('Pclass').mean()['Fare']
print(grouped_data)

# Handling missing values
titanic_df.isnull().sum()

# Sorting data
sorted_data = titanic_df.sort_values(by='Age', ascending=False)
print(sorted_data.head())
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# ...

# %%
# Scatter plot of age vs fare
sns.scatterplot(x='Age',
                y='Fare',
                data=titanic_df
               ).set(title='Age vs Fare')
# Out:
# [Text(0.5, 1.0, 'Age vs Fare')]

# %%
# Boxplot of age distribution by passenger class
sns.boxplot(x='Pclass',
            y='Age',
            data=titanic_df
           ).set(title='Age distribution by PClass')
# Out:
# [Text(0.5, 1.0, 'Age distribution by PClass')]

# %%
# Countplot of passager class
sns.countplot(x='Pclass',
              data=titanic_df
             ).set(title='PClass countplot')
# Out:
# [Text(0.5, 1.0, 'PClass countplot')]

# %%
# Pairplot of numerical variables
sns.pairplot(titanic_df[['Age',
                         'Fare',
                         'SibSp',
                         'Parch']])

# %%
# Heatmap of correlation matrix
correlation_matrix = titanic_df.corr()
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            linewidths=0.5
           ).set(title='Correlation matrix')
# Out:
# <ipython-input-27-eedac4646251>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = titanic_df.corr()
# [Text(0.5, 1.0, 'Correlation matrix')]

# %%
# Violin plot of age distribution by passenger class
sns.violinplot(x='Pclass',
               y='Age',
               data=titanic_df
              ).set(title='Age Distribution by Passenger Class (Violin Plot)')
# Out:
# [Text(0.5, 1.0, 'Age Distribution by Passenger Class (Violin Plot)')]
